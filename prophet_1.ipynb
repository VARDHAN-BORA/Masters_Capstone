# %%
# !pip install --quiet prophet

# %%
import pandas as pd
from prophet import Prophet
from tqdm import tqdm
import numpy as np
import os

# %%
# Step 1: Mount Google Drive (optional for saving results)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ✅ Prophet Forecast for All CPZ Stations (Daily, Improved)


# Step 2: Load Already Merged Yearly File
data_path = "/content/cpz_station_timeseries_2024_yearly_15min.csv"
df = pd.read_csv(data_path, parse_dates=["time_bucket"])
df.dropna(subset=["time_bucket"], inplace=True)
df['start_station_id'] = df['start_station_id'].astype(str)
print(f"✅ Loaded yearly data with shape: {df.shape}")

# Step 3: Resample to Daily Booking Counts
df_daily = df.set_index("time_bucket")
df_daily = df_daily.groupby("start_station_id").resample("D")["booking_count"].sum().reset_index()

# Step 4: Forecast Per Station Using Prophet (with log transform + cap)
forecast_horizon = 90  # days into future
output_dir = "/content/drive/MyDrive/citibike_project/forecast_output_2024"
os.makedirs(output_dir, exist_ok=True)

unique_stations = df_daily['start_station_id'].unique()
print(f"🔁 Running forecasts for {len(unique_stations)} stations...")

for station_id in tqdm(unique_stations):
    station_df = df_daily[df_daily['start_station_id'] == station_id][['time_bucket', 'booking_count']]
    station_df = station_df.rename(columns={"time_bucket": "ds", "booking_count": "y"})

    # Skip stations with insufficient data
    if len(station_df) < 30:
        continue

    try:
        # Replace 0s and log-transform
        station_df['y'] = station_df['y'].apply(lambda x: max(x, 0.1))
        station_df['y'] = np.log(station_df['y'])

        # Set cap for logistic growth
        station_df['cap'] = station_df['y'].max() * 1.2

        model = Prophet(growth='logistic')
        model.fit(station_df)

        future = model.make_future_dataframe(periods=forecast_horizon)
        future['cap'] = station_df['cap'].iloc[0]

        forecast = model.predict(future)

        # Reverse log transform
        forecast['yhat'] = np.exp(forecast['yhat'])
        forecast['yhat_lower'] = np.exp(forecast['yhat_lower'])
        forecast['yhat_upper'] = np.exp(forecast['yhat_upper'])

        forecast_out = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
        forecast_out['start_station_id'] = station_id

        # Save forecast
        output_file = f"{output_dir}/forecast_station_{station_id.replace(' ', '_')}.csv"
        forecast_out.to_csv(output_file, index=False)

    except Exception as e:
        print(f"❌ Error with station {station_id}: {e}")

print("✅ Forecasting complete! All files saved to:", output_dir)
# Out:
# <ipython-input-13-6e06df22f7f0>:9: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path, parse_dates=["time_bucket"])
# ✅ Loaded yearly data with shape: (15524343, 3)
# 🔁 Running forecasts for 2136 stations...
#   0%|          | 0/2136 [00:00<?, ?it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/oa5xiwws.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/18goceqd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99055', 'data', 'file=/tmp/tmp23x7_fip/oa5xiwws.json', 'init=/tmp/tmp23x7_fip/18goceqd.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_model081kwth1/prophet_model-20250325164758.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:47:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:47:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
#   0%|          | 2/2136 [00:00<09:45,  3.64it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/mn32yadx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/20rote8u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61196', 'data', 'file=/tmp/tmp23x7_fip/mn32yadx.json', 'init=/tmp/tmp23x7_fip/20rote8u.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_modelag3rsa0d/prophet_model-20250325164759.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:47:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:47:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
#   0%|          | 3/2136 [00:00<10:20,  3.44it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/cjeg81f4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/cf13i_w7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54015', 'data', 'file=/tmp/tmp23x7_fip/cjeg81f4.json', 'init=/tmp/tmp23x7_fip/cf13i_w7.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_model4p0d5nyq/prophet_model-20250325164759.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:47:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:47:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
#   0%|          | 4/2136 [00:01<11:39,  3.05it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/67n7ioj3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/c3oq4i24.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10485', 'data', 'file=/tmp/tmp23x7_fip/67n7ioj3.json', 'init=/tmp/tmp23x7_fip/c3oq4i24.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_mod
.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:48:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:48:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
#   2%|▏         | 34/2136 [00:13<12:04,  2.90it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/s4j7cqnx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/_jwlyxgf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75426', 'data', 'file=/tmp/tmp23x7_fip/s4j7cqnx.json', 'init=/tmp/tmp23x7_fip/_jwlyxgf.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_modelnn2ga8p9/prophet_model-20250325164812.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:48:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:48:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
#   2%|▏         | 35/2136 [00:14<12:40,  2.76it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/16o__vsl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/q9qvxh_j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22396', 'data', 'file=/tmp/tmp23x7_fip/16o__vsl.json', 'init=/tmp/tmp23x7_fip/q9qvxh_j.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_modeljr0or___/prophet_model-20250325164813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:48:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:48:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
#   2%|▏         | 36/2136 [00:14<13:05,  2.67it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/zajw52_q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/shosvb86.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1771', 'data', 'file=/tmp/tmp23x7_fip/zajw52_q.json', 'init=/tmp/tmp23x7_fip/shosvb86.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_model4yjozxkb/prophet_model-20250325164813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:48:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:48:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
#   2%|▏         | 37/2136 [00:15<13:42,  2.55it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/yg1xzl_o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/w3tgdmah.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22831', 'data', 'file=/tmp/tmp23x7_fip/yg1xzl_o.json', 'init=/tmp/tmp23x7_fip/w3tgdmah.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_modelmxbf_q9x/prophet_model-20250325164813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:48:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:48:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
#   2%|▏         | 38/2136 [00:15<13:37,  2.57it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/9sf9jw4z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/2ti_3zd4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# ...
#   forecast_out['start_station_id'] = station_id
#  99%|█████████▊| 2106/2136 [14:16<00:03,  7.61it/s]
# ❌ Error with station JC024: cap must be greater than floor (which defaults to 0).
#  99%|█████████▉| 2112/2136 [14:16<00:02,  9.95it/s]
# ❌ Error with station JC066: cap must be greater than floor (which defaults to 0).
#  99%|█████████▉| 2114/2136 [14:17<00:02, 10.43it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/wsq1bzng.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/w3gq4v85.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70774', 'data', 'file=/tmp/tmp23x7_fip/wsq1bzng.json', 'init=/tmp/tmp23x7_fip/w3gq4v85.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_modelo3955ghh/prophet_model-20250325170216.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:02:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:02:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
#  99%|█████████▉| 2121/2136 [14:18<00:01,  8.76it/s]
# ❌ Error with station JC093: cap must be greater than floor (which defaults to 0).
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/gb3yj3sk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/w9gpdpwk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51203', 'data', 'file=/tmp/tmp23x7_fip/gb3yj3sk.json', 'init=/tmp/tmp23x7_fip/w9gpdpwk.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_model5xwk2r6h/prophet_model-20250325170217.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:02:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:02:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
#  99%|█████████▉| 2123/2136 [14:18<00:02,  6.17it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/jdufeoz9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/i7v1q5zd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5897', 'data', 'file=/tmp/tmp23x7_fip/jdufeoz9.json', 'init=/tmp/tmp23x7_fip/i7v1q5zd.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_modelv6nund2d/prophet_model-20250325170217.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:02:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:02:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
#  99%|█████████▉| 2125/2136 [14:19<00:01,  5.56it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/6xtt3g61.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/i3n_7goz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11775', 'data', 'file=/tmp/tmp23x7_fip/6xtt3g61.json', 'init=/tmp/tmp23x7_fip/i3n_7goz.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_model7o4xxg9v/prophet_model-20250325170218.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:02:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# ❌ Error with station JC104: cap must be greater than floor (which defaults to 0).
# 17:02:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
# 100%|█████████▉| 2126/2136 [14:19<00:02,  3.58it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/0qy2u04e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/m0zd3hl4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67104', 'data', 'file=/tmp/tmp23x7_fip/0qy2u04e.json', 'init=/tmp/tmp23x7_fip/m0zd3hl4.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_modelbp3ztavs/prophet_model-20250325170218.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:02:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:02:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
# 100%|█████████▉| 2129/2136 [14:20<00:01,  4.84it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/axx03ne3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/699exy49.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# ❌ Error with station JC115: cap must be greater than floor (which defaults to 0).
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81604', 'data', 'file=/tmp/tmp23x7_fip/axx03ne3.json', 'init=/tmp/tmp23x7_fip/699exy49.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_model2s6mqpsy/prophet_model-20250325170219.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:02:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:02:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
# 100%|█████████▉| 2130/2136 [14:20<00:01,  3.99it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/roqkuk9s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/5iez6d5_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63693', 'data', 'file=/tmp/tmp23x7_fip/roqkuk9s.json', 'init=/tmp/tmp23x7_fip/5iez6d5_.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_modelj121q_ik/prophet_model-20250325170219.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:02:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:02:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
# 100%|█████████▉| 2131/2136 [14:21<00:01,  2.68it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/xqonlgfe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/g42szdzz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47284', 'data', 'file=/tmp/tmp23x7_fip/xqonlgfe.json', 'init=/tmp/tmp23x7_fip/g42szdzz.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_model0g8zg8_f/prophet_model-20250325170220.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:02:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:02:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
# 100%|█████████▉| 2132/2136 [14:21<00:01,  2.39it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/cc0mlye4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/bpj8z6cx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35871', 'data', 'file=/tmp/tmp23x7_fip/cc0mlye4.json', 'init=/tmp/tmp23x7_fip/bpj8z6cx.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_modelibu7slf9/prophet_model-20250325170220.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:02:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:02:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
# 100%|█████████▉| 2134/2136 [14:22<00:00,  2.73it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/1mhoq_0c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/mcpd91te.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72611', 'data', 'file=/tmp/tmp23x7_fip/1mhoq_0c.json', 'init=/tmp/tmp23x7_fip/mcpd91te.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_modelmf9q4_ua/prophet_model-20250325170221.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:02:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:02:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
# 100%|█████████▉| 2135/2136 [14:23<00:00,  2.40it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/cr6ok7_p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp23x7_fip/_mhfr3rm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88309', 'data', 'file=/tmp/tmp23x7_fip/cr6ok7_p.json', 'init=/tmp/tmp23x7_fip/_mhfr3rm.json', 'output', 'file=/tmp/tmp23x7_fip/prophet_modelqr9a71jq/prophet_model-20250325170222.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:02:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:02:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-13-6e06df22f7f0>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_out['start_station_id'] = station_id
# 100%|██████████| 2136/2136 [14:23<00:00,  2.47it/s]
# ✅ Forecasting complete! All files saved to: /content/drive/MyDrive/citibike_project/forecast_output_2024

# %%
# ✅ CPZ Forecast Simulation & Plotting

import pandas as pd
import matplotlib.pyplot as plt
import glob

# Step 1: Load All Forecast Files
data_path = "/content/drive/MyDrive/citibike_project/forecast_output_2024/*.csv"
forecast_files = glob.glob(data_path)

df_list = [pd.read_csv(f) for f in forecast_files]
df = pd.concat(df_list, ignore_index=True)
df['ds'] = pd.to_datetime(df['ds'])
df['start_station_id'] = df['start_station_id'].astype(str)

# Step 2: Filter Forecast to Post-CPZ Only (2025)
df = df[df['ds'] >= '2025-01-01'].copy()

# Step 3: Simulate CPZ Impact Scenarios
df['sim_low'] = df['yhat'] * 1.05
df['sim_mod'] = df['yhat'] * 1.15
df['sim_high'] = df['yhat'] * 1.30

# Step 4: Plot Forecast vs Simulated Demand for a Sample Station
station_id = '3199.01'  # Change this to any valid station ID
df_station = df[df['start_station_id'] == station_id]

if df_station.empty:
    print(f"⚠️ No forecast data found for station {station_id}")
else:
    plt.figure(figsize=(12, 6))
    plt.plot(df_station['ds'], df_station['yhat'], label='Baseline Forecast')
    plt.plot(df_station['ds'], df_station['sim_low'], label='+5% Scenario', linestyle='--')
    plt.plot(df_station['ds'], df_station['sim_mod'], label='+15% Scenario', linestyle='--')
    plt.plot(df_station['ds'], df_station['sim_high'], label='+30% Scenario', linestyle='--')
    plt.title(f"Station {station_id} Forecast vs CPZ Scenarios")
    plt.xlabel("Date")
    plt.ylabel("Predicted Bookings")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Optional: Save final merged + simulated dataset
output_file = "/content/drive/MyDrive/citibike_project/simulated_cpz_impact_2025.csv"
df.to_csv(output_file, index=False)
print(f"✅ Simulation data saved to: {output_file}")
# Out:
# ✅ Simulation data saved to: /content/drive/MyDrive/citibike_project/simulated_cpz_impact_2025.csv
