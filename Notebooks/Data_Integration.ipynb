# %%
import pandas as pd
import numpy as np
import glob

# %%
# Read Citi Bike Trip Data
df_citibike = pd.read_csv('/content/drive/MyDrive/Capstone /citibike_tripdata.csv')
print("✅ Citi Bike Data Loaded!")

df_citibike.info()
df_citibike.head()
# Out:
# <ipython-input-2-c88a0da02711>:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_citibike = pd.read_csv('/content/drive/MyDrive/Capstone /citibike_tripdata.csv')
# ✅ Citi Bike Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124475 entries, 0 to 2124474
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 210.7+ MB
# ...

# %%
# Read Cultural Data
df_cultural = pd.read_csv('/content/drive/MyDrive/Capstone /Cultural_Cleaned.csv')
print("\n✅ Cultural Data Loaded!")
df_cultural.info()
df_cultural.head(10)
# Out:
# ✅ Cultural Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          218 non-null    object
#  1   Neighborhood  218 non-null    object
#  2   Borough       218 non-null    object
#  3   Type          218 non-null    object
#  4   Summary       213 non-null    object
#  5   Full_Address  218 non-null    object
#  6   Latitude      93 non-null     float64
#  7   Longitude     93 non-null     float64
# dtypes: float64(2), object(6)
# memory usage: 13.8+ KB
#                                              Name        Neighborhood  \
# 0                      Metropolitan Museum of Art         Museum Mile
# 1                                 Brooklyn Museum       Crown Heights
# 2                            Staten Island Museum   West New Brighton
# 3                        Bronx Museum of the Arts   Concourse Village
# ...

# %%
# Read Parks Data
df_parks = pd.read_csv('/content/drive/MyDrive/Capstone /Parks.csv')
print("\n✅ Parks Data Loaded!")
df_parks.info()
df_parks.head(10)
# Out:
# ✅ Parks Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1071 entries, 0 to 1070
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          1071 non-null   object
#  1   Address       1071 non-null   object
#  2   Borough       1071 non-null   object
#  3   Latitude      1071 non-null   float64
#  4   Longitude     1071 non-null   float64
#  5   Full_Address  1071 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 50.3+ KB
#                      Name                      Address Borough   Latitude  \
# 0    Dyckman House Museum                4901 BROADWAY       M  53.773000
# 1  Volky Garden & Flowers           851 HORNADAY PLACE       X  40.846584
# 2           Elmhurst Park              78-01 57 AVENUE       Q  53.260972
# 3           John Jay Park              76-01 FDR DRIVE       M  40.795342
# ...

# %%
# Read Landmarks Data
df_landmarks = pd.read_csv('/content/drive/MyDrive/Capstone /Landmarks.csv')
print("\n✅ Landmarks Data Loaded!")
df_landmarks.info()
df_landmarks.head(10)
# Out:
# ✅ Landmarks Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       10 non-null     object
#  1   Address    10 non-null     object
#  2   Zipcode    10 non-null     int64
#  3   Latitude   10 non-null     float64
#  4   Longitude  10 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 532.0+ bytes
#                                                 Name  \
# 0                          Alice Austen House Museum
# 1                                  Flatiron Building
# 2                                        Museum Mile
# 3                                            The PIT
# 4                           Verrazano-Narrows Bridge
# 5              World Trade Center Transportation Hub
# 6  Washington Street between Front and Water Streets
# 7                  St. Ann & The Holy Trinity Church
# ...

# %%
# Read Subway Stations Data
df_subway = pd.read_csv('/content/drive/MyDrive/Capstone /MTA_Subway_Stations.csv')
print("\n✅ Subway Stations Data Loaded!")
df_subway.info()
df_subway.head(10)
# Out:
# ✅ Subway Stations Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GTFS Stop ID           496 non-null    object
#  1   Station ID             496 non-null    int64
#  2   Complex ID             496 non-null    int64
#  3   Division               496 non-null    object
#  4   Line                   496 non-null    object
#  5   Stop Name              496 non-null    object
#  6   Borough                496 non-null    object
#  7   CBD                    496 non-null    bool
#  8   Daytime Routes         496 non-null    object
#  9   Structure              496 non-null    object
#  10  GTFS Latitude          496 non-null    float64
#  11  GTFS Longitude         496 non-null    float64
#  12  North Direction Label  496 non-null    object
#  13  South Direction Label  496 non-null    object
# ...

# %%
# Read Bus Stops Data
df_bus_stops = pd.read_csv('/content/drive/MyDrive/Capstone /Bus_Stop_Shelter_20250304.csv')
print("\n✅ Bus Stops Data Loaded!")
df_bus_stops.info()
df_bus_stops.head(10)
# Out:
# ✅ Bus Stops Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3330 entries, 0 to 3329
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   the_geom    3330 non-null   object
#  1   BoroCode    3330 non-null   int64
#  2   BoroName    3330 non-null   object
#  3   BoroCD      3330 non-null   int64
#  4   CounDist    3330 non-null   int64
#  5   AssemDist   3330 non-null   int64
#  6   StSenDist   3330 non-null   int64
#  7   CongDist    3330 non-null   int64
#  8   Shelter_ID  3330 non-null   object
#  9   Corner      3330 non-null   object
#  10  On_Street   3330 non-null   object
#  11  Cross_Stre  3330 non-null   object
#  12  Longitude   3330 non-null   float64
#  13  Latitude    3330 non-null   float64
#  14  NTAName     3330 non-null   object
#  15  FEMAFldz    3330 non-null   object
#  16  FEMAFldT    3199 non-null   object
#  17  HrcEvac     1297 non-null   float64
# ...

# %%
# Read Pedestrian Counts Data
df_ped_counts = pd.read_csv('/content/drive/MyDrive/Capstone /PedCounts_per_Location.csv')
print("\n✅ Pedestrian Counts Data Loaded!")
df_ped_counts.info()
df_ped_counts.head(10)
# Out:
# ✅ Pedestrian Counts Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location_Name  31 non-null     object
#  1   May07_AM       31 non-null     int64
#  2   May07_PM       31 non-null     int64
#  3   Oct24_AM       31 non-null     int64
#  4   Oct24_PM       31 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.3+ KB
#                                        Location_Name  May07_AM  May07_PM  \
# 0  Broad Street / Beaver Street to South William ...      3469      3992
# 1         Broadway / Morris Street to Exchange Place      3660      8390
# 2  Chambers Street / West Broadway to Greenwich S...      7081      8512
# 3  Delancey Street / Orchard Street to Ludlow Street      1085      2733
# 4  East 14th Street / Fifth Avenue to University ...      2265     13723
# ...

# %%
# Read Transportation Sites Data
df_transport = pd.read_csv('/content/drive/MyDrive/Capstone /Transportation_Sites_20250304.csv')
print("\n✅ Transportation Sites Data Loaded!")
df_transport.info()
df_transport.head(10)
# Out:
# ✅ Transportation Sites Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22891 entries, 0 to 22890
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   School_Year                    22891 non-null  object
#  1   OPT_Code                       22891 non-null  object
#  2   Name                           22891 non-null  object
#  3   Affiliation                    20594 non-null  object
#  4   Site_Type                      22891 non-null  object
#  5   Street_Address                 22891 non-null  object
#  6   City                           22891 non-null  object
#  7   State                          22881 non-null  object
#  8   Zip                            22881 non-null  float64
#  9   Longitude                      22891 non-null  float64
#  10  Latitude                       22891 non-null  float64
# ...

# %%
# Read Recognized Shops Data
df_shops = pd.read_csv('/content/drive/MyDrive/Capstone /Recognized_Shop_Healthy_Stores_20250304.csv')
print("\n✅ Shops Data Loaded!")
df_shops.info()
df_shops.head(10)
# Out:
# ✅ Shops Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 709 entries, 0 to 708
# Data columns (total 14 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Store Name                                 709 non-null    object
#  1   Street Address                             709 non-null    object
#  2   Borough                                    709 non-null    object
#  3   Zip
# Code                                  709 non-null    int64
#  4   Year Awarded                               709 non-null    int64
#  5   Program
# Wave                              709 non-null    int64
#  6   Latitude                                   669 non-null    float64
#  7   Longitude                                  669 non-null    float64
#  8   Community Board                            635 non-null    float64
# ...

# %%
# Read Processed Weather Data
df_weather = pd.read_csv('/content/drive/MyDrive/Capstone /processed_weather_data.csv')
print("\n✅ Weather Data Loaded!")
df_weather.info()
df_weather.head(10)
# Out:
# ✅ Weather Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1886 entries, 0 to 1885
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DATE              1886 non-null   object
#  1   TMAX              1886 non-null   int64
#  2   TMIN              1886 non-null   int64
#  3   TAVG              1886 non-null   float64
#  4   PRCP              1886 non-null   float64
#  5   AWND              1886 non-null   float64
#  6   SNOW              1886 non-null   float64
#  7   Weather_Category  1886 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 118.0+ KB
#          DATE  TMAX  TMIN  TAVG  PRCP   AWND  SNOW Weather_Category
# 0  2020-01-01    41    34   0.0  0.00   8.50   0.0            Sunny
# 1  2020-01-02    49    33   0.0  0.00   5.37   0.0            Sunny
# 2  2020-01-03    49    44   0.0  0.15   3.36   0.0     Rainy, Foggy
# ...

# %%
# Read Shop Project Data
df_shop_project = pd.read_csv('/content/drive/MyDrive/Capstone /shop_project_20250304.csv')
print("\n✅ Shop Project Data Loaded!")
df_shop_project.info()
df_shop_project.head(10)
# Out:
# ✅ Shop Project Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unique Key                      49 non-null     int64
#  1   Created Date                    49 non-null     object
#  2   Closed Date                     49 non-null     object
#  3   Agency                          49 non-null     object
#  4   Agency Name                     49 non-null     object
#  5   Complaint Type                  49 non-null     object
#  6   Descriptor                      49 non-null     object
#  7   Location Type                   49 non-null     object
#  8   Incident Zip                    49 non-null     int64
#  9   Incident Address                45 non-null     object
#  10  Street Name                     45 non-null     object
# ...

# %%
# Read Cleaned Weather Data
df_weather_cleaned = pd.read_csv('/content/drive/MyDrive/Capstone /weather_data_cleaned (1).csv')
print("\n✅ Cleaned Weather Data Loaded!")
df_weather_cleaned.info()
df_weather_cleaned.head(10)
# Out:
# ✅ Cleaned Weather Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1886 entries, 0 to 1885
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  1886 non-null   object
#  1   NAME     1886 non-null   object
#  2   DATE     1886 non-null   object
#  3   AWND     1886 non-null   float64
#  4   PRCP     1886 non-null   float64
#  5   SNOW     1886 non-null   float64
#  6   SNWD     1886 non-null   float64
#  7   TAVG     1886 non-null   float64
#  8   TMAX     1886 non-null   int64
#  9   TMIN     1886 non-null   int64
#  10  WDF2     1886 non-null   float64
#  11  WDF5     1886 non-null   float64
#  12  WSF2     1886 non-null   float64
#  13  WSF5     1886 non-null   float64
# dtypes: float64(9), int64(2), object(3)
# memory usage: 206.4+ KB
#        STATION                         NAME        DATE   AWND  PRCP  SNOW  \
# 0  USW00094728  NY CITY CENTRAL PARK, NY US  2020-01-01   8.50  0.00   0.0
# ...

# %%
import pandas as pd

# ✅ Load Citi Bike Data
df_citibike = pd.read_csv('/content/drive/MyDrive/Capstone /citibike_tripdata.csv')
print("✅ Citi Bike Data Loaded!")
df_citibike.info()
df_citibike.head(10)
# Out:
# <ipython-input-14-92ecf54894fc>:4: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_citibike = pd.read_csv('/content/drive/MyDrive/Capstone /citibike_tripdata.csv')
# ✅ Citi Bike Data Loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124475 entries, 0 to 2124474
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 210.7+ MB
# ...

# %%
from scipy.spatial import cKDTree
import numpy as np

# ✅ Step 1: Drop conflicting columns BEFORE merging
conflicting_columns = [
    'Name', 'Latitude', 'Longitude',
    'Borough', 'Type', 'Summary', 'Full_Address', 'Neighborhood'
]
df_citibike.drop(columns=conflicting_columns, inplace=True, errors='ignore')

# ✅ Step 2: Clean data (remove NaN and infinity values)
df_citibike = df_citibike.dropna(subset=['start_lat', 'start_lng'])
df_cultural = df_cultural.dropna(subset=['Latitude', 'Longitude'])

df_citibike = df_citibike.replace([np.inf, -np.inf], np.nan).dropna(subset=['start_lat', 'start_lng'])
df_cultural = df_cultural.replace([np.inf, -np.inf], np.nan).dropna(subset=['Latitude', 'Longitude'])

# ✅ Step 3: Build KDTree for nearest neighbor search (for cultural data)
tree = cKDTree(df_cultural[['Latitude', 'Longitude']].values)

# ✅ Step 4: Find the closest cultural location for each Citi Bike station
distances, indices = tree.query(df_citibike[['start_lat', 'start_lng']].values)

# ✅ Step 5: Assign matched values
df_citibike['nearest_cultural_name'] = df_cultural.iloc[indices]['Name'].values
df_citibike['nearest_cultural_lat'] = df_cultural.iloc[indices]['Latitude'].values
df_citibike['nearest_cultural_lng'] = df_cultural.iloc[indices]['Longitude'].values
df_citibike['nearest_cultural_distance'] = distances  # (in degrees)

# ✅ Step 6: Merge using nearest coordinates
df_citibike = df_citibike.merge(
    df_cultural,
    left_on=['nearest_cultural_lat', 'nearest_cultural_lng'],
    right_on=['Latitude', 'Longitude'],
    how='left',
    suffixes=('_bike', '_cultural')
)

# ✅ Step 7: Drop unnecessary duplicate columns AFTER merge
df_citibike.drop(
    columns=[
        'Borough_bike', 'Type_bike', 'Full_Address_bike',
        'Neighborhood_bike', 'Summary_bike'
    ],
    inplace=True,
    errors='ignore'
)

# ✅ Step 8: Confirm result
print("✅ Cultural merge completed successfully!")
df_citibike.info()
df_citibike.head(10)
# Out:
# ✅ Cultural merge completed successfully!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2278083 entries, 0 to 2278082
# Data columns (total 25 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   ride_id                    object
#  1   rideable_type              object
#  2   started_at                 object
#  3   ended_at                   object
#  4   start_station_name         object
#  5   start_station_id           object
#  6   end_station_name           object
#  7   end_station_id             object
#  8   start_lat                  float64
#  9   start_lng                  float64
#  10  end_lat                    float64
#  11  end_lng                    float64
#  12  member_casual              object
#  13  nearest_cultural_name      object
#  14  nearest_cultural_lat       float64
#  15  nearest_cultural_lng       float64
#  16  nearest_cultural_distance  float64
#  17  Name                       object
# ...

# %%
from scipy.spatial import cKDTree
import numpy as np

# ✅ Step 1: Drop conflicting columns BEFORE merging
conflicting_columns = [
    'Name', 'Latitude', 'Longitude',
    'Borough', 'Type', 'Summary', 'Full_Address', 'Neighborhood'
]
df_citibike.drop(columns=conflicting_columns, inplace=True, errors='ignore')

# ✅ Step 2: Clean data (remove NaN and infinity values)
df_citibike = df_citibike.dropna(subset=['start_lat', 'start_lng'])
df_parks = df_parks.dropna(subset=['Latitude', 'Longitude'])

df_citibike = df_citibike.replace([np.inf, -np.inf], np.nan).dropna(subset=['start_lat', 'start_lng'])
df_parks = df_parks.replace([np.inf, -np.inf], np.nan).dropna(subset=['Latitude', 'Longitude'])

# ✅ Step 3: Build KDTree for nearest neighbor search (for parks)
tree = cKDTree(df_parks[['Latitude', 'Longitude']].values)

# ✅ Step 4: Find the closest park for each Citi Bike station
distances, indices = tree.query(df_citibike[['start_lat', 'start_lng']].values)

# ✅ Step 5: Assign matched values
df_citibike['nearest_park_name'] = df_parks.iloc[indices]['Name'].values
df_citibike['nearest_park_lat'] = df_parks.iloc[indices]['Latitude'].values
df_citibike['nearest_park_lng'] = df_parks.iloc[indices]['Longitude'].values
df_citibike['nearest_park_distance'] = distances  # (in degrees)

# ✅ Step 6: Merge using nearest coordinates
df_citibike = df_citibike.merge(
    df_parks,
    left_on=['nearest_park_lat', 'nearest_park_lng'],
    right_on=['Latitude', 'Longitude'],
    how='left',
    suffixes=('_bike', '_park')
)

# ✅ Step 7: Drop unnecessary duplicate columns AFTER merge
df_citibike.drop(
    columns=[
        'Borough_bike', 'Type_bike', 'Full_Address_bike',
        'Neighborhood_bike', 'Summary_bike'
    ],
    inplace=True,
    errors='ignore'
)

# ✅ Step 8: Confirm result
print("✅ Parks merge completed successfully!")
df_citibike.info()
df_citibike.head(10)
# Out:
# ✅ Parks merge completed successfully!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2663587 entries, 0 to 2663586
# Data columns (total 27 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   ride_id                    object
#  1   rideable_type              object
#  2   started_at                 object
#  3   ended_at                   object
#  4   start_station_name         object
#  5   start_station_id           object
#  6   end_station_name           object
#  7   end_station_id             object
#  8   start_lat                  float64
#  9   start_lng                  float64
#  10  end_lat                    float64
#  11  end_lng                    float64
#  12  member_casual              object
#  13  nearest_cultural_name      object
#  14  nearest_cultural_lat       float64
#  15  nearest_cultural_lng       float64
#  16  nearest_cultural_distance  float64
#  17  nearest_park_name          object
# ...

# %%
from scipy.spatial import cKDTree
import numpy as np

# ✅ Step 1: Drop conflicting columns BEFORE merging
conflicting_columns = [
    'Name', 'Latitude', 'Longitude',
    'Borough', 'Type', 'Summary', 'Full_Address', 'Neighborhood'
]
df_citibike.drop(columns=conflicting_columns, inplace=True, errors='ignore')

# ✅ Step 2: Clean data (remove NaN and infinity values)
df_citibike = df_citibike.dropna(subset=['start_lat', 'start_lng'])
df_landmarks = df_landmarks.dropna(subset=['Latitude', 'Longitude'])

df_citibike = df_citibike.replace([np.inf, -np.inf], np.nan).dropna(subset=['start_lat', 'start_lng'])
df_landmarks = df_landmarks.replace([np.inf, -np.inf], np.nan).dropna(subset=['Latitude', 'Longitude'])

# ✅ Step 3: Build KDTree for nearest neighbor search (for landmarks)
tree = cKDTree(df_landmarks[['Latitude', 'Longitude']].values)

# ✅ Step 4: Find the closest landmark for each Citi Bike station
distances, indices = tree.query(df_citibike[['start_lat', 'start_lng']].values)

# ✅ Step 5: Assign matched values
df_citibike['nearest_landmark_name'] = df_landmarks.iloc[indices]['Name'].values
df_citibike['nearest_landmark_lat'] = df_landmarks.iloc[indices]['Latitude'].values
df_citibike['nearest_landmark_lng'] = df_landmarks.iloc[indices]['Longitude'].values
df_citibike['nearest_landmark_distance'] = distances  # (in degrees)

# ✅ Step 6: Merge using nearest coordinates
df_citibike = df_citibike.merge(
    df_landmarks,
    left_on=['nearest_landmark_lat', 'nearest_landmark_lng'],
    right_on=['Latitude', 'Longitude'],
    how='left',
    suffixes=('_bike', '_landmark')
)

# ✅ Step 7: Drop unnecessary duplicate columns AFTER merge
df_citibike.drop(
    columns=[
        'Borough_bike', 'Type_bike', 'Full_Address_bike',
        'Neighborhood_bike', 'Summary_bike'
    ],
    inplace=True,
    errors='ignore'
)

# ✅ Step 8: Confirm result
print("✅ Landmarks merge completed successfully!")
df_citibike.info()
df_citibike.head(10)
# Out:
# ✅ Landmarks merge completed successfully!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2663587 entries, 0 to 2663586
# Data columns (total 31 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   ride_id                    object
#  1   rideable_type              object
#  2   started_at                 object
#  3   ended_at                   object
#  4   start_station_name         object
#  5   start_station_id           object
#  6   end_station_name           object
#  7   end_station_id             object
#  8   start_lat                  float64
#  9   start_lng                  float64
#  10  end_lat                    float64
#  11  end_lng                    float64
#  12  member_casual              object
#  13  nearest_cultural_name      object
#  14  nearest_cultural_lat       float64
#  15  nearest_cultural_lng       float64
#  16  nearest_cultural_distance  float64
#  17  nearest_park_name          object
# ...

# %%
# ✅ Rename columns to match expected format
df_subway.rename(
    columns={
        'GTFS Latitude': 'Latitude',
        'GTFS Longitude': 'Longitude'
    },
    inplace=True
)

# ✅ Proceed with the merge using the renamed columns
from scipy.spatial import cKDTree
import numpy as np

# ✅ Step 1: Drop conflicting columns BEFORE merging
conflicting_columns = [
    'Name', 'Latitude', 'Longitude',
    'Borough', 'Type', 'Summary', 'Full_Address', 'Neighborhood'
]
df_citibike.drop(columns=conflicting_columns, inplace=True, errors='ignore')

# ✅ Step 2: Clean data (remove NaN and infinity values)
df_citibike = df_citibike.dropna(subset=['start_lat', 'start_lng'])
df_subway = df_subway.dropna(subset=['Latitude', 'Longitude'])

df_citibike = df_citibike.replace([np.inf, -np.inf], np.nan).dropna(subset=['start_lat', 'start_lng'])
df_subway = df_subway.replace([np.inf, -np.inf], np.nan).dropna(subset=['Latitude', 'Longitude'])

# ✅ Step 3: Build KDTree for nearest neighbor search (for subway stations)
tree = cKDTree(df_subway[['Latitude', 'Longitude']].values)

# ✅ Step 4: Find the closest subway station for each Citi Bike station
distances, indices = tree.query(df_citibike[['start_lat', 'start_lng']].values)

# ✅ Step 5: Assign matched values
df_citibike['nearest_subway_name'] = df_subway.iloc[indices]['Stop Name'].values
df_citibike['nearest_subway_lat'] = df_subway.iloc[indices]['Latitude'].values
df_citibike['nearest_subway_lng'] = df_subway.iloc[indices]['Longitude'].values
df_citibike['nearest_subway_distance'] = distances  # (in degrees)

# ✅ Step 6: Merge using nearest coordinates
df_citibike = df_citibike.merge(
    df_subway,
    left_on=['nearest_subway_lat', 'nearest_subway_lng'],
    right_on=['Latitude', 'Longitude'],
    how='left',
    suffixes=('_bike', '_subway')
)

# ✅ Step 7: Drop unnecessary duplicate columns AFTER merge
df_citibike.drop(
    columns=[
        'Borough_bike', 'Type_bike', 'Full_Address_bike',
        'Neighborhood_bike', 'Summary_bike'
    ],
    inplace=True,
    errors='ignore'
)

# ✅ Step 8: Confirm result
print("✅ Subway stations merge completed successfully!")
df_citibike.info()
df_citibike.head(10)
# Out:
# ✅ Subway stations merge completed successfully!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2689767 entries, 0 to 2689766
# Data columns (total 51 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   ride_id                    object
#  1   rideable_type              object
#  2   started_at                 object
#  3   ended_at                   object
#  4   start_station_name         object
#  5   start_station_id           object
#  6   end_station_name           object
#  7   end_station_id             object
#  8   start_lat                  float64
#  9   start_lng                  float64
#  10  end_lat                    float64
#  11  end_lng                    float64
#  12  member_casual              object
#  13  nearest_cultural_name      object
#  14  nearest_cultural_lat       float64
#  15  nearest_cultural_lng       float64
#  16  nearest_cultural_distance  float64
#  17  nearest_park_name          object
# ...

# %%
# ✅ Rename columns to match expected format
df_bus_stops.rename(
    columns={
        'latitude': 'Latitude',
        'longitude': 'Longitude'
    },
    inplace=True
)

from scipy.spatial import cKDTree
import numpy as np

# ✅ Step 1: Drop conflicting columns BEFORE merging
conflicting_columns = [
    'Name', 'Latitude', 'Longitude',
    'Borough', 'Type', 'Summary', 'Full_Address', 'Neighborhood'
]
df_citibike.drop(columns=conflicting_columns, inplace=True, errors='ignore')

# ✅ Step 2: Clean data (remove NaN and infinity values)
df_citibike = df_citibike.dropna(subset=['start_lat', 'start_lng'])
df_bus_stops = df_bus_stops.dropna(subset=['Latitude', 'Longitude'])

df_citibike = df_citibike.replace([np.inf, -np.inf], np.nan).dropna(subset=['start_lat', 'start_lng'])
df_bus_stops = df_bus_stops.replace([np.inf, -np.inf], np.nan).dropna(subset=['Latitude', 'Longitude'])

# ✅ Step 3: Build KDTree for nearest neighbor search (for bus stops)
tree = cKDTree(df_bus_stops[['Latitude', 'Longitude']].values)

# ✅ Step 4: Find the closest bus stop for each Citi Bike station
distances, indices = tree.query(df_citibike[['start_lat', 'start_lng']].values)

# ✅ Step 5: Assign matched values
df_citibike['nearest_bus_stop_name'] = df_bus_stops.iloc[indices]['On_Street'].values
df_citibike['nearest_bus_lat'] = df_bus_stops.iloc[indices]['Latitude'].values
df_citibike['nearest_bus_lng'] = df_bus_stops.iloc[indices]['Longitude'].values
df_citibike['nearest_bus_distance'] = distances  # (in degrees)

# ✅ Step 6: Merge using nearest coordinates
df_citibike = df_citibike.merge(
    df_bus_stops,
    left_on=['nearest_bus_lat', 'nearest_bus_lng'],
    right_on=['Latitude', 'Longitude'],
    how='left',
    suffixes=('_bike', '_bus')
)

# ✅ Step 7: Drop unnecessary duplicate columns AFTER merge
df_citibike.drop(
    columns=[
        'Borough_bike', 'Type_bike', 'Full_Address_bike',
        'Neighborhood_bike', 'Summary_bike'
    ],
    inplace=True,
    errors='ignore'
)

# ✅ Step 8: Confirm result
print("✅ Bus stops merge completed successfully!")
df_citibike.info()
df_citibike.head(10)
# Out:
# ✅ Bus stops merge completed successfully!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2689767 entries, 0 to 2689766
# Data columns (total 70 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   ride_id                    object
#  1   rideable_type              object
#  2   started_at                 object
#  3   ended_at                   object
#  4   start_station_name         object
#  5   start_station_id           object
#  6   end_station_name           object
#  7   end_station_id             object
#  8   start_lat                  float64
#  9   start_lng                  float64
#  10  end_lat                    float64
#  11  end_lng                    float64
#  12  member_casual              object
#  13  nearest_cultural_name      object
#  14  nearest_cultural_lat       float64
#  15  nearest_cultural_lng       float64
#  16  nearest_cultural_distance  float64
#  17  nearest_park_name          object
# ...

# %%
# ✅ Step 1: Drop conflicting columns BEFORE merging
conflicting_columns = [
    'Location_Name', 'Borough', 'Type', 'Summary', 'Full_Address', 'Neighborhood'
]
df_citibike.drop(columns=conflicting_columns, inplace=True, errors='ignore')

# ✅ Step 2: Clean up formatting for matching
df_citibike['start_station_name'] = df_citibike['start_station_name'].str.strip().str.lower()
df_ped_counts['Location_Name'] = df_ped_counts['Location_Name'].str.strip().str.lower()

# ✅ Step 3: Merge using 'Location_Name' instead of coordinates
df_citibike = df_citibike.merge(
    df_ped_counts,
    left_on='start_station_name',
    right_on='Location_Name',
    how='left',
    suffixes=('_bike', '_ped')
)

# ✅ Step 4: Drop unnecessary duplicate columns AFTER merge
df_citibike.drop(
    columns=[
        'Location_Name'
    ],
    inplace=True,
    errors='ignore'
)

# ✅ Step 5: Confirm result
print("✅ Pedestrian Counts merge completed successfully!")
df_citibike.info()
df_citibike.head(10)
# Out:
# ✅ Pedestrian Counts merge completed successfully!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2689767 entries, 0 to 2689766
# Data columns (total 74 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   ride_id                    object
#  1   rideable_type              object
#  2   started_at                 object
#  3   ended_at                   object
#  4   start_station_name         object
#  5   start_station_id           object
#  6   end_station_name           object
#  7   end_station_id             object
#  8   start_lat                  float64
#  9   start_lng                  float64
#  10  end_lat                    float64
#  11  end_lng                    float64
#  12  member_casual              object
#  13  nearest_cultural_name      object
#  14  nearest_cultural_lat       float64
#  15  nearest_cultural_lng       float64
#  16  nearest_cultural_distance  float64
#  17  nearest_park_name          object
# ...

# %%
from scipy.spatial import cKDTree
import numpy as np

# ✅ Step 1: Drop conflicting columns BEFORE merging
conflicting_columns = [
    'Name', 'Latitude', 'Longitude',
    'Borough', 'Type', 'Summary', 'Full_Address', 'Neighborhood'
]
df_citibike.drop(columns=conflicting_columns, inplace=True, errors='ignore')

# ✅ Step 2: Clean data (remove NaN and infinity values)
df_citibike = df_citibike.dropna(subset=['start_lat', 'start_lng'])
df_transport = df_transport.dropna(subset=['Latitude', 'Longitude'])

df_citibike = df_citibike.replace([np.inf, -np.inf], np.nan).dropna(subset=['start_lat', 'start_lng'])
df_transport = df_transport.replace([np.inf, -np.inf], np.nan).dropna(subset=['Latitude', 'Longitude'])

# ✅ Step 3: Build KDTree for nearest neighbor search (for transport sites)
tree = cKDTree(df_transport[['Latitude', 'Longitude']].values)

# ✅ Step 4: Find the closest transport site for each Citi Bike station
distances, indices = tree.query(df_citibike[['start_lat', 'start_lng']].values)

# ✅ Step 5: Assign matched values
df_citibike['nearest_transport_name'] = df_transport.iloc[indices]['Name'].values
df_citibike['nearest_transport_lat'] = df_transport.iloc[indices]['Latitude'].values
df_citibike['nearest_transport_lng'] = df_transport.iloc[indices]['Longitude'].values
df_citibike['nearest_transport_distance'] = distances  # (in degrees)

# ✅ Step 6: Merge using nearest coordinates
df_citibike = df_citibike.merge(
    df_transport,
    left_on=['nearest_transport_lat', 'nearest_transport_lng'],
    right_on=['Latitude', 'Longitude'],
    how='left',
    suffixes=('_bike', '_transport')
)

# ✅ Step 7: Drop unnecessary duplicate columns AFTER merge
df_citibike.drop(
    columns=[
        'Borough_bike', 'Type_bike', 'Full_Address_bike',
        'Neighborhood_bike', 'Summary_bike'
    ],
    inplace=True,
    errors='ignore'
)

# ✅ Step 8: Confirm result
print("✅ Transportation sites merge completed successfully!")
df_citibike.info()
df_citibike.head(10)
# Out:
# ✅ Transportation sites merge completed successfully!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17541239 entries, 0 to 17541238
# Data columns (total 94 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   ride_id                        object
#  1   rideable_type                  object
#  2   started_at                     object
#  3   ended_at                       object
#  4   start_station_name             object
#  5   start_station_id               object
#  6   end_station_name               object
#  7   end_station_id                 object
#  8   start_lat                      float64
#  9   start_lng                      float64
#  10  end_lat                        float64
#  11  end_lng                        float64
#  12  member_casual                  object
#  13  nearest_cultural_name          object
#  14  nearest_cultural_lat           float64
#  15  nearest_cultural_lng           float64
# ...

# %%
# ✅ Step 6: Ensure Timestamps Align for Weather Data
# Convert both 'started_at' in Citibike and 'DATE' in Weather to datetime
df_citibike['started_at'] = pd.to_datetime(df_citibike['started_at'])
df_weather['DATE'] = pd.to_datetime(df_weather['DATE'])

# Merge weather data using the nearest timestamp method (Merge AsOf)
df_citibike = pd.merge_asof(
    df_citibike.sort_values('started_at'),
    df_weather.sort_values('DATE'),
    left_on='started_at',
    right_on='DATE',
    direction='backward'  # Adjust this direction based on your data logic
)

# ✅ Step 7: Handle duplicate columns after merge (if needed)
df_citibike.drop(
    columns=['DATE'],  # Drop the 'DATE' column if it's no longer needed
    inplace=True,
    errors='ignore'
)

# ✅ Step 8: Confirm result
print("✅ Weather merge completed successfully!")
df_citibike.info()  # Check the column names and data types
df_citibike.head(10)  # Display the first 10 rows of the merged data
# Out:
# ✅ Weather merge completed successfully!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17541239 entries, 0 to 17541238
# Columns: 110 entries, ride_id to Weather_Category_y
# dtypes: bool(1), datetime64[ns](3), float64(38), int64(16), object(52)
# memory usage: 14.3+ GB
#             ride_id rideable_type              started_at  \
# 0  8A37006C7A32066B  classic_bike 2024-12-30 23:41:25.635
# 1  8A37006C7A32066B  classic_bike 2024-12-30 23:41:25.635
# 2  8A37006C7A32066B  classic_bike 2024-12-30 23:41:25.635
# 3  8A37006C7A32066B  classic_bike 2024-12-30 23:41:25.635
# 4  8A37006C7A32066B  classic_bike 2024-12-30 23:41:25.635
# 5  8A37006C7A32066B  classic_bike 2024-12-30 23:41:25.635
# 6  8A37006C7A32066B  classic_bike 2024-12-30 23:41:25.635
# 7  8A37006C7A32066B  classic_bike 2024-12-30 23:41:25.635
# 8  8A37006C7A32066B  classic_bike 2024-12-30 23:41:25.635
# 9  8A37006C7A32066B  classic_bike 2024-12-30 23:41:25.635
#
# ...
